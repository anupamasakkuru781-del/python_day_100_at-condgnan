# %%
s = "CODEGNAN"
# Out:
# CODEGNAN

# %%
print(s)
# Out:
# CODEGNAN

# %%
string operations
string

# %%
# concation
s1= "code"
s2= "Gnan"
s3=s1+"  "+s2
print(s3)
# Out:
# code  Gnan

# %%
print(s1+s1+s1)
# Out:
# codecodecode

# %%
s="codegnan"
print(s[0])
s[0]='z'
print(s)
# Out:
# c
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 s="codegnan"
#       2 print(s[0])
# ----> 3 s[0]='z'
#       4 print(s)
#
# TypeError: 'str' object does not support item assignment

# %%
s1="CODE"
print("z"+s1[1:])
# Out:
# zODE

# %%
s1="CODE"
print(s*10)
# Out:
# codegnancodegnancodegnancodegnancodegnancodegnancodegnancodegnancodegnancodegnan

# %%
print('code'+'3')
# Out:
# code3

# %%
# string functions
- case conversion functions-lower(),upper(),title(),swapcase(),capitalize()

# %%
s="T am python BATCH studenT"
print(s.lower())
print(s.upper())
print(s.title())
print(s.swapcase())
print(s.capitalize())
# Out:
# t am python batch student
# T AM PYTHON BATCH STUDENT
# T Am Python Batch Student
# t AM PYTHON batch STUDENt
# T am python batch student

# %%
# sub string index finding
# find()
s = "I am python BATCH studenT"
print(s.find("t"))
# Out:
# 7

# %%
# strip()

# %%
# split() - it returns the list of substring and it separetes the string with sep
s =    "@@@@@@@@co@  @egnan@@@@@@@"
print(s)
print(s.splitt())
print(s.split('@'))
print(s.split('n'))
# Out:
# @@@@@@@@co@  @egnan@@@@@@@
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 4>()
#       2 s =    "@@@@@@@@co@  @egnan@@@@@@@"
#       3 print(s)
# ----> 4 print(s.splitt())
#       5 print(s.split('@'))
#       6 print(s.split('n'))
#
# AttributeError: 'str' object has no attribute 'splitt'

# %%
# case checking functions
s1= "CODE"
s2="gnan"
s3="123"
s4="abc123"
s5="Codegnan"
print(s1.isupper())
print(s2.isupper())
print(s1.islower())
print(s2.islower())
print(s3.isdigit())
print(s4.isdigit())
print(s4.isalnum())
print(s4.isalpha())
print(s5.isalpha())
# Out:
# True
# False
# False
# True
# True
# False
# True
# False
# True

# %%
's' in 'sring'
# Out:
# True

# %%
'sri' in'string'
# Out:
# False

# %%
# username validation
       = minimum length - 8
    = atleast one upper case and one lower case letter
    = special charctes ('-', '@')
    = it contains digits
# password validation

# %%
s = input()  # sribu#@123
validate_string = "qwertyuioplkjhgfdsazxcvbnmQWERTYUIOPLKJHGFDSAZXCVBNM1234567890@_"
if len(s) >= 8:
       # check atleast one upper case and one lower case letters
           # - first charectes is upper or lower 
        if s[0].isupper() or s[0].islower():s
            for i in range(1, len(s)):
                if s[i] not in  validate_string:
                    print(f"Invalid username beacuse chacreter {s[i]}")
                    breaks
                else:
                        print("valid usernames")
# Out:
#   Input In [15]
#     for i in range(1, len(s)):
#     ^
# IndentationError: unexpected indent

# %%
 # - special charctes ('_', '@')
            # - it contains digits
        else:
            print("username not valid because first charcter is not upper or not lower")
        else:
            print("username not vaild because length is lesser ")

# %%
s=input() #srinu#@123
validdate_string+"qwertyuioplkjhgfdsazxcvbnmQWERTYUIOPLKJHGFDSAZXCVBNM1234567890@_"
if len(s)>=8:
    # check atleast one upper case and one lower case letter
    # -first charcter is upper or lower
    if s[0].isupper() or s[0].islower():
        for i in range(1,len(s)):
            if s[i] not in validate_string:
                print(f"Invaild username because character {s[i]}")
                break
            else:
                print("valid username")
