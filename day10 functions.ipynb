# %%
def addition (a,b):
    return a+b
def subtraction (a,b):
    return a-b
def multiplication (a,b):
    return a*b

def division(a,b):
    if b==0:
        return "zero division not possible"
    return a/b
    print("Welcome to small level calculation")
    n1int(input("enter number1:"))
    n2=int(input("enter number2:"))
    print("1.addition  /n  2.substraction  /n  3.multiplication  /n  4.division")
    choice=int(input("enter your choice"))
    if choice==1:
        print("sum of two numbers is:",addition(n1,n2))
        elif choice==2:
            print("substraction of two numbers is:",substraction(n1,n2))
            elif choice==3:
                print("multiplication of two numbers is:",multiplication(n1,n2))
                elif choice==4:
                    print("division of two numbers is:",division(n1,n2))
                    else:
                        print("please select correct operator")
