# %%
class Bank:
    bank_name = "Codegnan Bank"
    def __init__(self, username, password, amount):
        self.username = username
        self._password = password
        self.__amount = amount
    def balance(self):
        return f"Current Balance is {self.__amount}"
    def withdraw(self, withdraw_amount):
        if self.__amount >= withdraw_amount:
            self.__amount -= withdraw_amount
            return f"{withdraw_amount} withdraw successfully and current balance is{self.__amount}"
        return "Insufficient Funds"
    def deposite(self, deposite_amount):
        self.__amount += desposite-amount
        return f"{desposit_amount} Desposite successfully and curreny balance is {self.__amount}"
    def __total_users(self):
        return "Bank total users are 80"
user = Bank("Anu", "anu@123", 2000)
print(user.balance())
print(user.withdraw(500))
print(user._password)
# name handling
print(user.bank_name)
print(user._Bank__total_users())
# Out:
# Current Balance is 2000
# 500 withdraw successfully and current balance is1500
# anu@123
# Codegnan Bank
# Bank total users are 80
